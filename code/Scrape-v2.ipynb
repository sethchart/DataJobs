# %%
import requests
from bs4 import BeautifulSoup
from fake_headers import Headers
from numpy import random
import time
header = Headers()
from JobsDb import JobsDb
db = JobsDb()

def get_page(url, params=None):
    headers = header.generate()
    page = requests.get(url, params=params, headers=headers).content
    return page

def get_search_page(page_number=1):
    params = {
        'l': 'USA',
        'sort': 'date',
        'p': page_number
    }
    url = 'https://www.careerjet.com/search/jobs'
    page = get_page(url, params=params)
    return page

def get_jobs_from_page(page):
    soup = BeautifulSoup(page, 'html.parser')
    jobs = soup.find_all('article', class_='job clicky')
    return jobs

def get_link_from_job(job):
    raw_link = job.find('h2').find('a', href=True)
    url = 'https://www.careerjet.com'+raw_link['href']
    title = raw_link['title']
    link = {
        'url': url,
        'title': title
    }
    return link

def get_description(url):
    """Given a url for a careerjet job listing. This function will
    scrape the full job description form the page.
    """
    wait_time = random.rand(1)
    time.sleep(wait_time)
    page = get_page(url)
    soup = BeautifulSoup(page, 'html.parser')
    description = soup.find('section', class_='content').text
    return description

def scrape_search_page(page_number=1):
    page = get_search_page(page_number=page_number)
    jobs = get_jobs_from_page(page)
    scraped_jobs = []
    for job in jobs:
        try:
            link = get_link_from_job(job)
            title = link['title']
            url = link['url']
            description = get_description(url)
            job_dict = {
                'title': title,
                'url': url,
                'description': description
            }
            db.write_row_to_table(table_name='jobs', row_dict=job_dict)
        except:
            continue

def scrape_site(number_of_pages=2):
    for page_number in range(1, number_of_pages+1):
        scrape_search_page(page_number=page_number)

# %%
scrape_site()

# %%
db.load_table_as_df('jobs')
# Out:
#     id                                              title  \
# 0    1           Commercial Masonry Restoration Estimator
# 1    2                                 Part-Time Delivery
# 2    3         Flexible Schedule - Deliver with Uber Eats
# 3    4                         Food Delivery - Weekly Pay
# 4    5                             Deliver with Uber Eats
# 5    6                        Deliver Food with Uber Eats
# 6    7                Part-Time Food Delivery - Uber Eats
# 7    8             Research Technician - Genomic Medicine
# 8    9                                 Part-Time Delivery
# 9   10                             Deliver with Uber Eats
# 10  11                             Deliver with Uber Eats
# 11  12                             Deliver with Uber Eats
# 12  13                        Deliver Food with Uber Eats
# 13  14         Flexible Schedule - Deliver with Uber Eats
# 14  15                     Truck Driver CDL A - Dedicated
# 15  16                                        Dialysis RN
# 16  17                                         ICU/CCU RN
# 17  18        Project Engineer - Nationwide Opportunities
# 18  19                 Content Manager - COVID-19 Testing
# 19  20                            Maintenance Technicians
# 20  21                                 Research Scientist
# 21  22                                      Data Engineer
# 22  23                   Mobile Developer - iOS & Android
# 23  24  Warehouse Worker (Night Shifts Only) - Benefit...
# 24  25  Warehouse Team Member (Full-Time) - Earn $15/h...
# 30  https://www.careerjet.com/jobad/us86ddef156bdd...
# 31  https://www.careerjet.com/jobad/us61a1281940cd...
# 32  https://www.careerjet.com/jobad/us0e058a9eb7b4...
# 33  https://www.careerjet.com/jobad/us18488dc5c0fd...
# 34  https://www.careerjet.com/jobad/usa024a4b3c4ee...
# 35  https://www.careerjet.com/jobad/us0122cc97647d...
# 36  https://www.careerjet.com/jobad/us4bfaa48cd508...
# 37  https://www.careerjet.com/jobad/us5660830d1aee...
#
#                                           description
# 0   \n  \n    Job Description Great Opportunity! E...
# 1   \n  \n    Deliver with Uber. Earn on your sche...
# 2   \n  \n    Deliver with Uber. Earn on your sche...
# 3   \n  \n    Deliver with Uber. Earn on your sche...
# 4   \n  \n    Deliver with Uber. Earn on your sche...
# 5   \n  \n    Deliver with Uber. Earn on your sche...
# 6   \n  \n    Deliver with Uber. Earn on your sche...
# 7   \n  \n    The mission of The University of Tex...
# 8   \n  \n    Deliver with Uber. Earn on your sche...
# 9   \n  \n    Deliver with Uber. Earn on your sche...
# 10  \n  \n    Deliver with Uber. Earn on your sche...
# 11  \n  \n    Deliver with Uber. Earn on your sche...
# 12  \n  \n    Deliver with Uber. Earn on your sche...
# 13  \n  \n    Deliver with Uber. Earn on your sche...
# 14  \n  \n    Hogan is Now Hiring CDL A Truck Driv...
# 15  \n  \n    trustaff is currently seeking an exp...
# 16  \n  \n    trustaff is currently seeking an exp...
# 17  \n  \n    Amazon created one of the most sophi...
# 18  \n  \n    Amazon is focused on protecting the ...
# 19  \n  \n    Pennrose Management Company is excit...
# 20  \n  \n    External job description Amazon Lab1...
# 21  \n  \n    Amazon Web Services (AWS) provides c...
# 22  \n  \n    If you are a Mobile Developer with e...
# 23  \n  \n    Warehouse Associate Hourly pay rate:...
# 24  \n  \n    Warehouse Associate Hourly pay rate:...
# 25  \n  \n    Full-Time Warehouse Team Member - $6...
# 26  \n  \n    Would you like to kickstart your car...
# 27  \n  \n    GROWTH OPPORTUNITIES AROUND EVERY CO...
# 28  \n  \n    About Joe Hudsons Collision Centers ...
# 29  \n  \n    Position Purpose: Would you like to ...
# 30  \n  \n    Warehouse Team Members - New Locatio...
# 31  \n  \n    Hogan is Now Hiring CDL A Truck Driv...
# 32  \n  \n    Hogan is Now Hiring CDL A Truck Driv...
# 33  \n  \n    Hogan is Now Hiring CDL A Truck Driv...
# 34  \n  \n    Hogan is Now Hiring CDL A Truck Driv...
# 35  \n  \n    Deliver with Uber. Earn on your sche...
# 36  \n  \n    Deliver with Uber. Earn on your sche...
# 37  \n  \n    Deliver with Uber. Earn on your sche...

# %%
db.close()
